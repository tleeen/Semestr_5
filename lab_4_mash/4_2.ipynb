# %% [markdown]
# #### No2 (5 баллов)
# ##### Скачайте файл с данными о публикациях на сайте Хабрахабр (https://cloud.mail.ru/public/3ViL/q5xSM1TH2). Выполните следующие действия:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
# %matplotlib inline

# %% [markdown]
# ##### 1. Изучите датасет, попробуйте понять какой столбец за что отвечает.

# %%
df = pd.read_csv("howpop_train.csv")
df
# Out:
#                                                      url        domain  \
# 0                       https://habrahabr.ru/post/18284/  habrahabr.ru
# 1                       https://habrahabr.ru/post/18285/  habrahabr.ru
# 2                       https://habrahabr.ru/post/18286/  habrahabr.ru
# 3                       https://habrahabr.ru/post/18291/  habrahabr.ru
# 4                       https://geektimes.ru/post/18294/  geektimes.ru
# ...                                                  ...           ...
# 134132  https://habrahabr.ru/company/mailru/blog/314014/  habrahabr.ru
# 134133                 https://geektimes.ru/post/282086/  geektimes.ru
# 134134                 https://geektimes.ru/post/282090/  geektimes.ru
# 134135                 https://geektimes.ru/post/282092/  geektimes.ru
# 134136                 https://habrahabr.ru/post/314088/  habrahabr.ru
#
#         post_id            published      author     flow  polling  \
# ...

# %% [markdown]
# ##### 2. Удалите столбцы, названия которых заканчиваются на _lognorm. Выберите их с помощью filter() и удалите drop-ом:

# %%
df.drop(
    filter(lambda c: c.endswith("_lognorm"), df.columns),
    axis=1,  # axis = 1: столбцы
    inplace=True,
)  # избавляет от необходимости сохранять датасет
df
# Out:
#                                                      url        domain  \
# 0                       https://habrahabr.ru/post/18284/  habrahabr.ru
# 1                       https://habrahabr.ru/post/18285/  habrahabr.ru
# 2                       https://habrahabr.ru/post/18286/  habrahabr.ru
# 3                       https://habrahabr.ru/post/18291/  habrahabr.ru
# 4                       https://geektimes.ru/post/18294/  geektimes.ru
# ...                                                  ...           ...
# 134132  https://habrahabr.ru/company/mailru/blog/314014/  habrahabr.ru
# 134133                 https://geektimes.ru/post/282086/  geektimes.ru
# 134134                 https://geektimes.ru/post/282090/  geektimes.ru
# 134135                 https://geektimes.ru/post/282092/  geektimes.ru
# 134136                 https://habrahabr.ru/post/314088/  habrahabr.ru
#
#         post_id            published      author     flow  polling  \
# ...

# %% [markdown]
# ##### 3. Столбец published (время публикации) содержит строки. Чтобы работать с этими данными как с датой/временем публикации, приведите их к типу datetime:

# %%
df["published"] = pd.to_datetime(df.published, yearfirst=True)
df
# Out:
#                                                      url        domain  \
# 0                       https://habrahabr.ru/post/18284/  habrahabr.ru
# 1                       https://habrahabr.ru/post/18285/  habrahabr.ru
# 2                       https://habrahabr.ru/post/18286/  habrahabr.ru
# 3                       https://habrahabr.ru/post/18291/  habrahabr.ru
# 4                       https://geektimes.ru/post/18294/  geektimes.ru
# ...                                                  ...           ...
# 134132  https://habrahabr.ru/company/mailru/blog/314014/  habrahabr.ru
# 134133                 https://geektimes.ru/post/282086/  geektimes.ru
# 134134                 https://geektimes.ru/post/282090/  geektimes.ru
# 134135                 https://geektimes.ru/post/282092/  geektimes.ru
# 134136                 https://habrahabr.ru/post/314088/  habrahabr.ru
#
#         post_id           published      author     flow  polling  \
# ...

# %% [markdown]
# ##### 4. Создайте несколько столбцов на основе данных о времени публикации:

# %%
df["year"] = [d.year for d in df.published]
df["month"] = [d.month for d in df.published]

df["dayofweek"] = [d.isoweekday() for d in df.published]
df["hour"] = [d.hour for d in df.published]
df
# Out:
#                                                      url        domain  \
# 0                       https://habrahabr.ru/post/18284/  habrahabr.ru
# 1                       https://habrahabr.ru/post/18285/  habrahabr.ru
# 2                       https://habrahabr.ru/post/18286/  habrahabr.ru
# 3                       https://habrahabr.ru/post/18291/  habrahabr.ru
# 4                       https://geektimes.ru/post/18294/  geektimes.ru
# ...                                                  ...           ...
# 134132  https://habrahabr.ru/company/mailru/blog/314014/  habrahabr.ru
# 134133                 https://geektimes.ru/post/282086/  geektimes.ru
# 134134                 https://geektimes.ru/post/282090/  geektimes.ru
# 134135                 https://geektimes.ru/post/282092/  geektimes.ru
# 134136                 https://habrahabr.ru/post/314088/  habrahabr.ru
#
#         post_id           published      author     flow  polling  \
# ...

# %% [markdown]
# ##### 5. Используя Seaborn, постройте визуализацию и покажите в каком месяце (и какого года) было больше всего публикаций.

# %%
data = df[['year', 'month']]

t = sb.FacetGrid(data, col='year', col_wrap=4)
t.map(sb.countplot, 'month')
# Out:
# c:\Users\ISeven\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ##### 6. Используя Seaborn, постройте график зависимости числа публикаций от дня недели, используя параметр hue

# %%
sb.countplot(x="dayofweek", hue="dayofweek", data=df)
plt.show()

# %% [markdown]
# ##### 7. Используя Seaborn, проведите визуальный анализ и отметьте верные утверждения про данный датасет:
# - Больше всего просмотров набирают статьи, опубликованные в 12 часов дня
# - У опубликованных в 10 утра постов больше всего комментариев
# - Больше всего просмотров набирают статьи, опубликованные в 6 часов утра
# - Максимальное число комментариев на гиктаймсе набрала статья, опубликованная в 9 часов вечера
# - На хабре дневные статьи комментируют чаще, чем вечерние

# %%
sb.barplot(x=df["hour"], y=df["views"])
plt.show()

# %% [markdown]
#  - Больше всего просмотров набирают статьи, опубликованные в 12 часов дня - Неверно
#
#  - Больше всего просмотров набирают статьи, опубликованные в 6 часов утра - Верно

# %%
sb.barplot(x=df["hour"], y=df["comments"])
plt.show()

# %% [markdown]
#  - У опубликованных в 10 утра постов больше всего комментариев - Неверно
#
#  - На хабре дневные статьи комментируют чаще, чем вечерние - Неверно

# %%
domains = df.groupby("domain")
data = domains.get_group("geektimes.ru")

sb.barplot(x=df["hour"], y=df["comments"])
plt.show()

# %% [markdown]
# - Максимальное число комментариев на гиктаймсе набрала статья, опубликованная в 9 часов вечера - Неверно

# %% [markdown]
# ##### 8. Используя Seaborn, проведите визуальный анализ и определите кого из топ-20 авторов чаще всего минусуют?

# %%
authors = df.groupby(["author"], as_index=False).count().sort_values(
    by="url", ascending=False)["author"][:20].to_list()  # top 20 authors

data = df[df["author"].apply(lambda x: x in authors)]
sb.barplot(data=data, y="author", x="votes_minus", orient="h")
plt.show()

# %% [markdown]
# ##### 9. Используя Seaborn, сравните субботы и понедельники. Правда ли, что по субботам авторы пишут в основном днём, а по понедельникам — в основном вечером?

# %%
sb.violinplot(x=df["dayofweek"], y=df["hour"])
plt.show()

# %% [markdown]
# - Неправда
