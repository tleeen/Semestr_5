# %% [markdown]
# ## **Лабораторная работа 3**
#
# ### (10 баллов)

# %% [markdown]
# #### No1 (5 баллов)
# Выполните задания из файла https://cloud.mail.ru/public/vt9e/vS12exFen.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
# %matplotlib inline

# %% [markdown]
# Пример 1. Просмотрите типы доступных в Seaborn наборов данных,
# скопируйте их и вставьте в результат примера 1.

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# Пример 2. Импортируйте набор данных 'iris'. Наборы данных загружаются как Pandas DataFrame по умолчанию.
#
# а) Импорт набора данных 'iris'

# %%
data = sb.load_dataset("iris")
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# б) Импорт набора данных 'tips' – чаевые

# %%
df = sb.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Пример 3. Постройте изображение с настройками по умолчанию в
# Matplotlib:

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)


sinplot()
plt.show()

# %% [markdown]
# Пример 4. Измените тот же график на значения по умолчанию в
# Seaborn, используя функцию set():

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)


sb.set()
sinplot()
plt.show()

# %% [markdown]
# Различается фон

# %% [markdown]
# Пример 5. Применим стиль "whitegrid"

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)


sb.set_style("whitegrid")
sinplot()
plt.show()

# %% [markdown]
# Отличаются цвета сетки

# %% [markdown]
# Пример 6.

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)


sb.set_style("white")
sinplot()
sb.despine()
plt.show()

# %% [markdown]
# Пример 7. Выполните инструкцию:

# %%
sb.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': False,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %% [markdown]
# style - стиль ("whitegrid", ...)
#
# rc - переопределение значений словаря стилей seaborn

# %% [markdown]
# Изменение значений любого параметра изменит стиль графика.
#
# Пример 8.

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)


sb.set_style("darkgrid", {'axes.axisbelow': False})  # Изменили здесь
sinplot()
sb.despine()
plt.show()

# %% [markdown]
# Сравните два изображения: из примера 8 и примера 9. В чем отличие?
#
# Пример 9.

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)


sb.set_style("darkgrid", {'axes.axisbelow': True})  # Изменили здесь
sinplot()
sb.despine()
plt.show()

# %% [markdown]
# В примере 8 сетка отображается над графиками. В примере 9 наоборот

# %% [markdown]
# Пример 10.

# %%
current_palette = sb.color_palette()
sb.palplot(current_palette)
plt.show()

# %% [markdown]
# По умолчанию отобразилось 10 цветов

# %% [markdown]
# Пример 11. а) Выведите рисунок последовательной палитры.

# %%
sb.palplot(sb.color_palette("Greens"))
plt.show()

# %% [markdown]
# б) Выберите другой цвет и приведите изображение
# последовательной палитры.

# %%
sb.palplot(sb.color_palette("Blues"))
plt.show()

# %% [markdown]
# Пример 12. а) Выведите рисунок расходящейся палитры.

# %%
sb.palplot(sb.color_palette("BrBG", 7))
plt.show()

# %% [markdown]
# б) Приведите рисунок расходящейся палитры с другим сочетанием
# цветов.

# %%
sb.palplot(sb.color_palette("PiYG_r", 7))
plt.show()

# %% [markdown]
# Пример 13.

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i)*flip)


sb.set_style("white")
sb.set_palette("husl")
sinplot()
plt.show()

# %% [markdown]
# Пример 14.

# %%
sb.set()
# Набор данных 'чаевые'
tips = sb.load_dataset('tips')
ax = sb.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()

# %% [markdown]
# В среднем чем больше сумма чека, тем больше чаевые

# %% [markdown]
# Пример 15. Поиграем с параметрами:

# %%
df = sb.load_dataset('iris')
sb.displot(df['petal_length'], kde=False)
plt.show()

# %% [markdown]
# Частота встречаемости ирисов по длине лепестков

# %% [markdown]
# Пример 16. Играем с параметрами:

# %%
df = sb.load_dataset('iris')
sb.kdeplot(df['petal_length'])
plt.show()

# %% [markdown]
# График плотности для длины лепестков ириса

# %% [markdown]
# Пример 17. Продолжаем играть с параметрами:

# %% [markdown]
# а) Прокомментируйте программный код и полученный рисунок.

# %%
df = sb.load_dataset('iris')  # загрузка датасета iris
sb.distplot(df['petal_length'])  # отрисовка по столбцу petal_length
plt.show()  # вывод
# Out:
# C:\Users\ISeven\AppData\Local\Temp\ipykernel_2652\1869306223.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df['petal_length'])  # отрисовка по столбцу petal_length

# %% [markdown]
# б) Сравните два рисунка а) и б).

# %%
df = sb.load_dataset('iris')
sb.distplot(df['petal_length'], hist_kws={"alpha": 1})
plt.show()
# Out:
# C:\Users\ISeven\AppData\Local\Temp\ipykernel_2652\3673949875.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df['petal_length'], hist_kws={"alpha": 1})

# %% [markdown]
# На рисунке Б гистограмма полностью непрозрачна

# %% [markdown]
# Пример 18.

# %%
df = sb.load_dataset('iris')
sb.jointplot(x='petal_length', y='petal_width', data=df)
plt.show()

# %% [markdown]
# Прямая связь между длиной и шириной лепестка

# %% [markdown]
# Пример 19

# %%
df = sb.load_dataset('iris')
sb.set_style("ticks")
sb.pairplot(df, hue='species', diag_kind="kde", kind="scatter", palette="husl")
plt.show()

# %% [markdown]
# Пример 20. По тем же данным постройте другую матрицу точечной
# диаграммы.

# %%
iris = sb.load_dataset("iris")
ax = sb.pairplot(iris)
plt.show()

# %% [markdown]
# В примере 20 значения не стилизованы

# %% [markdown]
# Пример 21.

# %%
df = sb.load_dataset('iris')
sb.stripplot(x="species", y="petal_length", data=df, jitter=False)
plt.show()

# %% [markdown]
# Пример 22.

# %%
df = sb.load_dataset('iris')
sb.stripplot(x="species", y="petal_length", data=df, jitter=True)
plt.show()

# %% [markdown]
# Пример 23.

# %%
df = sb.load_dataset('iris')
sb.swarmplot(x="species", y="petal_length", data=df)
plt.show()
# Out:
# c:\Users\ISeven\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3543: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Пример 24.

# %%
df = sb.load_dataset('iris')
sb.barplot(x="species", y="petal_length", data=df)
plt.show()

# %% [markdown]
# Пример 25. а) По тем же данным постройте коробчатую диаграмму

# %%
df = sb.load_dataset('iris')
sb.boxplot(x="species", y="petal_length", data=df)
plt.show()

# %% [markdown]
# Медианы:
# - 1.5
# - 4.4
# - 5.6
#
# Концы доверительных интервалов:
# - 1.2 - 1.7
# - 3.3 - 5.1
# - 4.6 - 6.9

# %% [markdown]
# б) Постройте boxplot с другим расположением коробок

# %%
df = sb.load_dataset('iris')
sb.boxplot(data=df, orient="h")
plt.show()

# %% [markdown]
# Пример 26.

# %%
df = sb.load_dataset('tips')
sb.violinplot(x="day", y="total_bill", data=df)
plt.show()

# %% [markdown]
# Пример 27.

# %%
df = sb.load_dataset('tips')
sb.violinplot(x="day", y="total_bill", hue='sex', data=df)
plt.show()

# %% [markdown]
# В среднем у мужчин больше сумма чека

# %% [markdown]
# Пример 28. Построим гистограмму среднего числа выживших мужчин и
# женщин в каждом классе кают.

# %%
df = sb.load_dataset('titanic')
sb.barplot(x="sex", y="survived", hue="class", data=df)
plt.show()

# %% [markdown]
# Выжило больше женщин. Процент выживаемости пассажиров первого класса наибольший

# %% [markdown]
# Пример 29.

# %%
df = sb.load_dataset('titanic')
sb.countplot(x="class", data=df, palette="Blues")
plt.show()

# %% [markdown]
# Больше всего пассажиров было в третьем классе. Меньше всего во втором

# %% [markdown]
# Пример 30.

# %%
df = sb.load_dataset('titanic')
sb.pointplot(x="sex", y="survived", hue="class", data=df)
plt.show()

# %% [markdown]
# Информация одинаковая

# %% [markdown]
# Пример 31. Построим regplot и затем lmplot по одним и тем же данным.

# %%
df = sb.load_dataset('tips')
sb.regplot(x="total_bill", y="tip", data=df)
sb.lmplot(x="total_bill", y="tip", data=df)
plt.show()

# %% [markdown]
# На втором рисунке нет верхней и правой рамок

# %% [markdown]
# Пример 32. Построим линейную регрессию, когда одна из переменных
# принимает дискретные значения

# %%
df = sb.load_dataset('tips')
sb.lmplot(x="size", y="tip", data=df)
plt.show()

# %% [markdown]
# Пример 33.

# %%
df = sb.load_dataset('anscombe')
sb.lmplot(x="x", y="y", data=df.query("dataset == 'I'"))
plt.show()

# %% [markdown]
# Из-за недостаточного количества представленных данных, сложно оценить, наскольно хорошо данные подходят для модели линейной регрессии

# %% [markdown]
# Пример 34.

# %%
df = sb.load_dataset('anscombe')
sb.lmplot(x="x", y="y", data=df.query("dataset == 'II'"))
plt.show()

# %% [markdown]
# а) Точки не очень хорошо ложаться на линию регрессии
#
# б) Большое отклонение точек данных от линии регрессии
#
# в) Парабола
